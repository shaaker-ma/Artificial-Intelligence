# %%
import time
import copy
import queue
import numpy
from math import *
class Node(object):
    def __init__(self, _state):
        self.state = tuple(_state)
        self.parent = None
        self.depth = 0
        self.h = 0
        self.ballsHave = set()
        self.ballsPlaced = set()
    def setParent(self, _Node):
        self.parent = _Node
    def setDepth(self, _depth):
        self.depth = _depth
    def setHeuristic(self, _h):
        self.h = _h
    def setBallsHave(self,parentBalls):
        (self.ballsHave).update(parentBalls)
    def setBallsPlaced(self, parentBallsPlaced):
        (self.ballsPlaced).update(parentBallsPlaced)
    def addBallsHave(self, pickedBall):
        (self.ballsHave).add(pickedBall)
    def removeBallsHave(self, droppedBall):
        (self.ballsHave).remove(droppedBall)
    def addBallsPlaced(self, placedBall):
        (self.ballsPlaced).add(placedBall)
    def getState(self):
        return self.state
    def getParent(self):
        return self.parent
    def getDepth(self):
        return self.depth
    def getHeuristic(self):
        return self.h 
    def getBallsHave(self):
        return self.ballsHave
    def getBallsPlaced(self):
        return self.ballsPlaced
    def printState(self):
        print(self.state)
    def printPath(self,Node):
        while(Node.parent != None):
            Node.printState()
            Node = Node.parent
        Node.printState()

# %%
def firstHeuristic(node, finalPointNode, ballsPos): #Manhattan
    if(len(ballsPos) == 0):
        return (node.getState()[0]-finalPointNode.getState()[0])+(node.getState()[1]-finalPointNode.getState()[1])
    ballsLeftToBePlaced = []
    distances = []
    for ball in ballsPos:
        if(ball not in node.getBallsHave()):
            if(ballsPos[ball] not in node.getBallsPlaced()):
                ballsLeftToBePlaced.append(ball)
    sumDist = []
    for i in range(len(distances)): #DistFromBalls
        sumDist.append((node.getState()[0]-distances[i][0])+ (node.getState()[1]-distances[i][1]))
    sumDist.append((node.getState()[0]-finalPointNode.getState()[0])+(node.getState()[1]-finalPointNode.getState()[1]))
    return sum(sumDist)

# %%
def secondHeuristic(node, finalPointNode, ballsPos): #Euclidean
    if(len(ballsPos) == 0):
        return (node.getState()[0]-finalPointNode.getState()[0])**2 + (node.getState()[1]-finalPointNode.getState()[1])**2
    ballsLeftToBePlaced = []
    distances = []
    for ball in ballsPos:
        if(ball not in node.getBallsHave()):
            if(ballsPos[ball] not in node.getBallsPlaced()):
                ballsLeftToBePlaced.append(ball)
    sumDist = []
    for i in range(len(distances)): #DistFromBalls
        sumDist.append((node.getState()[0]-distances[i][0])**2 + (node.getState()[1]-distances[i][1])**2)
    sumDist.append((node.getState()[0]-finalPointNode.getState()[0])**2 + (node.getState()[1]-finalPointNode.getState()[1])**2)
    return sum(sumDist)

# %%
def pathAvailable(node, maze):
    n, m = len(maze), len(maze[0])
    state = node.getState()
    if((state[0] >=0 and state[0] < n) and (state[1] >=0 and state[1] < m)): 
        if(maze[state[0]][state[1]] != '*'): 
            return True
    return False
def goalTest(node, finalPointNode, ballsPos):
    if(len(node.getBallsPlaced()) == len(ballsPos)): #All balls in right place
        if(node.getState() == finalPointNode.getState()): #Reached goalPoint
            return True
    return False

# %% [markdown]
# ##  <font color='brown'>Part E: First A* </font>

# %%
def Astar_1(startPointNode, finalPointNode, bagCapacity, numBalls, ballsPos, maze):
    frontier = []
    frontierSet = set() #ONLY saves hash(ballsPlaced + ballsHave + state)
    explored = set() #ONLY saves hash(ballsPlaced + ballsHave + state)
    actions = [[0,1],[1,0],[0,-1],[-1,0]] # right-down-left-up
    solDistance, stateSeen, stateSeenUnique = 0,0,0
    startPointNode.setHeuristic(firstHeuristic(startPointNode,finalPointNode,ballsPos)+startPointNode.getDepth())
    frontier.append(startPointNode)
    frontierSet.add(hash(str(startPointNode.getBallsPlaced())+str(startPointNode.getBallsHave())+str(startPointNode.getState())))
    if(goalTest(startPointNode, finalPointNode, ballsPos)):
        return 0,1,1
    while(frontier):
        node = frontier.pop() #Every Iteration minimum Heuristic goes to the end of list
        if(node.getParent()):
            print("node: ",node.getState()," parent: ",((node.getParent()).getState())," ballsHave:",node.getBallsHave())
        if(hash(str(node.getBallsPlaced())+str(node.getBallsHave())+str(node.getState())) in frontierSet):
            frontierSet.remove(hash(str(node.getBallsPlaced())+str(node.getBallsHave())+str(node.getState())))
        explored.add(hash(str(node.getBallsPlaced())+str(node.getBallsHave())+str(node.getState())))
        if(node.getState() in node.getBallsHave()):
            node.addBallsPlaced(node.getState())
            node.removeBallsHave(node.getState())
        for action in actions:
            child = Node([node.getState()[0]+action[0], node.getState()[1]+action[1]])
            child.setParent(node)
            child.setDepth(node.getDepth()+1)
            child.setBallsHave(node.getBallsHave())
            child.setBallsPlaced(node.getBallsPlaced())
            stateSeen = stateSeen+1
            if((hash(str(child.getBallsPlaced())+str(child.getBallsHave())+str(child.getState())) not in explored) 
               and (hash(str(child.getBallsPlaced())+str(child.getBallsHave())+str(child.getState())) not in frontierSet)): 
                if(pathAvailable(child,maze)):
                   stateSeenUnique = stateSeenUnique+1
                   if(goalTest(child, finalPointNode, ballsPos)):
#                        child.printPath(child)
                       solDistance = child.getDepth()
                       return solDistance, stateSeen, stateSeenUnique
                   child.setHeuristic(firstHeuristic(child,finalPointNode,ballsPos)+child.getDepth())
                   for i in range(len(frontier)):
                       if((child.getHeuristic() < frontier[i].getHeuristic()) or(i == len(frontier)-1) ):
                           frontier.insert(i,child)
                           frontierSet.add(hash(str(child.getBallsPlaced())+str(child.getBallsHave())+str(child.getState())))
                           break
                   if(len(frontier) == 0):
                       frontier.append(child)
                       frontierSet.add(hash(str(child.getBallsPlaced())+str(child.getBallsPlaced())+str(child.getBallsHave())+str(child.getState())))
            ####### Ball handing
            if((action == [-1,0]) and (len(node.getBallsHave())<bagCapacity)):
                if((action == [-1,0]) and (node.getState() in ballsPos) and (node.getState() not in child.getBallsHave()) and (node.getState() not in child.getBallsPlaced())):
                    child_withBall = Node([node.getState()[0],node.getState()[1]])
                    child_withBall.setParent(node)
                    child_withBall.setDepth(node.getDepth()+1)
                    child_withBall.setBallsHave(node.getBallsHave())
                    child_withBall.setBallsPlaced(node.getBallsPlaced())
                    stateSeen = stateSeen+1
                    ballPicked = ballsPos.get(node.getState()) 
                    child_withBall.addBallsHave(ballPicked)
                    child_withBall.setHeuristic(firstHeuristic(child_withBall,finalPointNode,ballsPos)+child_withBall.getDepth())
                    for i in range(len(frontier)):
                       if((child_withBall.getHeuristic() < frontier[i].getHeuristic()) or(i == len(frontier)-1) ):
                           frontier.insert(i,child_withBall)
                           frontierSet.add(hash(str(child_withBall.getBallsPlaced())+str(child_withBall.getBallsHave())+str(child_withBall.getState())))
    return -1, stateSeen, stateSeenUnique

# %%
M=3
print("\n\nmap",M,": ")
mazeName = str(M)+".txt"
file = open(mazeName,'r')
lines = file.readlines()
count = 0
countBallsTemp =0
for line in lines:
    line = line.split()
    if(count ==0):
        n, m = int(line[0]),int(line[1])
        maze = []
        count +=1
    elif(count ==1):
        startPoint = [int(line[0]),int(line[1])]
        count +=1
    elif(count == 2):
        finalPoint = [int(line[0]),int(line[1])]
        count +=1
    elif(count == 3):
        bagCapacity = int(line[0])
        count +=1
    elif(count == 4):
        numBalls = int(line[0])
        countBallsTemp = numBalls
        ballsPos = {}
        count +=1
    elif(count >4 and countBallsTemp>0):
        ballsPos.update({(int(line[0]),int(line[1])):(int(line[2]),int(line[3]))})
        countBallsTemp -=1
        count +=1
    else:
        maze.append(line)
timeConsumed = []
# for i in range(3):
startPointNode = Node(startPoint)
finalPointNode = Node(finalPoint)
bagCapacity_map = bagCapacity
numBalls_map = numBalls
ballsPos_map = ballsPos
startTime = time.time()
solDistance, stateSeen, stateSeenUnique = Astar_1(startPointNode, finalPointNode, bagCapacity_map, numBalls_map, ballsPos_map, maze)
endTime = time.time()
timeConsumed.append(endTime-startTime)
print("solDistance",solDistance)
print("stateSeen",stateSeen)
print("stateSeenUnique",stateSeenUnique)
print("time it took:",(endTime-startTime),"sec")
print("\nAvg time for three operations:",(sum(timeConsumed)),"sec")
print("\n---------------------------------------------------------\n")
# Out:
# map 3 :
# node:  (1, 2)  parent:  (1, 1)  ballsHave: set()
# node:  (2, 1)  parent:  (1, 1)  ballsHave: set()
# node:  (2, 2)  parent:  (1, 2)  ballsHave: set()
# node:  (1, 3)  parent:  (1, 2)  ballsHave: set()
# node:  (2, 3)  parent:  (2, 2)  ballsHave: set()
# node:  (1, 4)  parent:  (1, 3)  ballsHave: set()
# node:  (2, 4)  parent:  (2, 3)  ballsHave: set()
# node:  (1, 5)  parent:  (1, 4)  ballsHave: set()
# node:  (2, 5)  parent:  (2, 4)  ballsHave: set()
# node:  (1, 6)  parent:  (1, 5)  ballsHave: set()
# node:  (2, 6)  parent:  (2, 5)  ballsHave: set()
# node:  (1, 7)  parent:  (1, 6)  ballsHave: set()
# node:  (2, 7)  parent:  (2, 6)  ballsHave: set()
# node:  (1, 8)  parent:  (1, 7)  ballsHave: set()
# node:  (2, 8)  parent:  (2, 7)  ballsHave: set()
# node:  (1, 9)  parent:  (1, 8)  ballsHave: set()
# node:  (2, 9)  parent:  (2, 8)  ballsHave: set()
# node:  (1, 10)  parent:  (1, 9)  ballsHave: set()
# node:  (2, 10)  parent:  (2, 9)  ballsHave: set()
# node:  (1, 11)  parent:  (1, 10)  ballsHave: set()
# node:  (2, 11)  parent:  (2, 10)  ballsHave: set()
# node:  (1, 12)  parent:  (1, 11)  ballsHave: set()
# node:  (2, 12)  parent:  (2, 11)  ballsHave: set()
# node:  (1, 13)  parent:  (1, 12)  ballsHave: set()
# node:  (2, 13)  parent:  (2, 12)  ballsHave: set()
# node:  (1, 14)  parent:  (1, 13)  ballsHave: set()
# node:  (2, 14)  parent:  (2, 13)  ballsHave: set()
# node:  (1, 15)  parent:  (1, 14)  ballsHave: set()
# node:  (2, 15)  parent:  (2, 14)  ballsHave: set()
# node:  (1, 16)  parent:  (1, 15)  ballsHave: set()
# node:  (2, 16)  parent:  (2, 15)  ballsHave: set()
# node:  (1, 17)  parent:  (1, 16)  ballsHave: set()
# node:  (2, 17)  parent:  (2, 16)  ballsHave: set()
# node:  (1, 18)  parent:  (1, 17)  ballsHave: set()
# node:  (2, 18)  parent:  (2, 17)  ballsHave: set()
# node:  (1, 19)  parent:  (1, 18)  ballsHave: set()
# node:  (2, 19)  parent:  (2, 18)  ballsHave: set()
# node:  (1, 20)  parent:  (1, 19)  ballsHave: set()
# node:  (2, 20)  parent:  (2, 19)  ballsHave: set()
# node:  (1, 21)  parent:  (1, 20)  ballsHave: set()
# node:  (2, 21)  parent:  (2, 20)  ballsHave: set()
# node:  (1, 22)  parent:  (1, 21)  ballsHave: set()
# node:  (2, 22)  parent:  (2, 21)  ballsHave: set()
# node:  (1, 23)  parent:  (1, 22)  ballsHave: set()
# node:  (2, 23)  parent:  (2, 22)  ballsHave: set()
# node:  (1, 24)  parent:  (1, 23)  ballsHave: set()
# node:  (2, 24)  parent:  (2, 23)  ballsHave: set()
# node:  (1, 25)  parent:  (1, 24)  ballsHave: set()
# node:  (2, 25)  parent:  (2, 24)  ballsHave: set()
# node:  (1, 26)  parent:  (1, 25)  ballsHave: set()
# node:  (2, 26)  parent:  (2, 25)  ballsHave: set()
# node:  (1, 27)  parent:  (1, 26)  ballsHave: set()
# node:  (2, 27)  parent:  (2, 26)  ballsHave: set()
# node:  (1, 28)  parent:  (1, 27)  ballsHave: set()
# node:  (2, 28)  parent:  (2, 27)  ballsHave: set()
# node:  (1, 29)  parent:  (1, 28)  ballsHave: set()
# node:  (2, 29)  parent:  (2, 28)  ballsHave: set()
# node:  (1, 30)  parent:  (1, 29)  ballsHave: set()
# node:  (2, 30)  parent:  (2, 29)  ballsHave: set()
# node:  (1, 31)  parent:  (1, 30)  ballsHave: set()
# node:  (2, 31)  parent:  (2, 30)  ballsHave: set()
# node:  (1, 32)  parent:  (1, 31)  ballsHave: set()
# node:  (2, 32)  parent:  (2, 31)  ballsHave: set()
# node:  (1, 33)  parent:  (1, 32)  ballsHave: set()
# node:  (2, 33)  parent:  (2, 32)  ballsHave: set()
# node:  (1, 34)  parent:  (1, 33)  ballsHave: set()
# node:  (2, 34)  parent:  (2, 33)  ballsHave: set()
# node:  (1, 35)  parent:  (1, 34)  ballsHave: set()
# node:  (2, 35)  parent:  (2, 34)  ballsHave: set()
# node:  (1, 36)  parent:  (1, 35)  ballsHave: set()
# node:  (2, 36)  parent:  (2, 35)  ballsHave: set()
# node:  (1, 37)  parent:  (1, 36)  ballsHave: set()
# node:  (2, 37)  parent:  (2, 36)  ballsHave: set()
# node:  (1, 38)  parent:  (1, 37)  ballsHave: set()
# node:  (2, 38)  parent:  (2, 37)  ballsHave: set()
# node:  (1, 39)  parent:  (1, 38)  ballsHave: set()
# node:  (2, 39)  parent:  (2, 38)  ballsHave: set()
# node:  (1, 40)  parent:  (1, 39)  ballsHave: set()
# node:  (2, 40)  parent:  (2, 39)  ballsHave: set()
# node:  (1, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (2, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 40)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (2, 40)  parent:  (2, 39)  ballsHave: set()
# node:  (2, 40)  parent:  (1, 40)  ballsHave: {(2, 39)}
# node:  (1, 40)  parent:  (2, 40)  ballsHave: set()
# node:  (2, 39)  parent:  (2, 40)  ballsHave: set()
# node:  (1, 39)  parent:  (2, 39)  ballsHave: set()
# node:  (2, 38)  parent:  (2, 39)  ballsHave: set()
# node:  (1, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (2, 37)  parent:  (2, 38)  ballsHave: set()
# node:  (2, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 40)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 38)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (2, 40)  parent:  (1, 40)  ballsHave: {(2, 39)}
# node:  (2, 38)  parent:  (1, 38)  ballsHave: {(2, 39)}
# node:  (1, 37)  parent:  (1, 38)  ballsHave: {(2, 39)}
# node:  (2, 37)  parent:  (2, 38)  ballsHave: {(2, 39)}
# node:  (1, 36)  parent:  (1, 37)  ballsHave: {(2, 39)}
# node:  (2, 36)  parent:  (2, 37)  ballsHave: {(2, 39)}
# node:  (1, 35)  parent:  (1, 36)  ballsHave: {(2, 39)}
# node:  (2, 35)  parent:  (2, 36)  ballsHave: {(2, 39)}
# node:  (1, 34)  parent:  (1, 35)  ballsHave: {(2, 39)}
# node:  (2, 34)  parent:  (2, 35)  ballsHave: {(2, 39)}
# node:  (1, 33)  parent:  (1, 34)  ballsHave: {(2, 39)}
# node:  (2, 33)  parent:  (2, 34)  ballsHave: {(2, 39)}
# node:  (1, 32)  parent:  (1, 33)  ballsHave: {(2, 39)}
# node:  (2, 32)  parent:  (2, 33)  ballsHave: {(2, 39)}
# node:  (1, 31)  parent:  (1, 32)  ballsHave: {(2, 39)}
# node:  (2, 31)  parent:  (2, 32)  ballsHave: {(2, 39)}
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 39)}
# node:  (2, 30)  parent:  (2, 31)  ballsHave: {(2, 39)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 39)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 39)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 39)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 39)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 39)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 39)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 39)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 39)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 39)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 39)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 39)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 39)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 39)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 39)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 39)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 39)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 39)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 39)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 39)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 39)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 39)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 39)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 39)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 39)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 39)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 39)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 39)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 39)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 39)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 39)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 39)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 39)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 39)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 39)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 39)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 39)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 39)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 39)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 39)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 39)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 39)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 39)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 39)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 39)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 39)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 39)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 39)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 39)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 39)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 39)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 39)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 39)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 39)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 39)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 39)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 39)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 39)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 39)}
# node:  (1, 37)  parent:  (2, 37)  ballsHave: set()
# node:  (2, 36)  parent:  (2, 37)  ballsHave: set()
# node:  (1, 37)  parent:  (1, 37)  ballsHave: {(2, 37)}
# node:  (2, 35)  parent:  (2, 36)  ballsHave: set()
# node:  (2, 37)  parent:  (1, 37)  ballsHave: {(2, 37)}
# node:  (1, 38)  parent:  (1, 37)  ballsHave: {(2, 37)}
# node:  (2, 38)  parent:  (2, 37)  ballsHave: set()
# node:  (2, 38)  parent:  (1, 38)  ballsHave: {(2, 37)}
# node:  (2, 39)  parent:  (2, 38)  ballsHave: set()
# node:  (2, 39)  parent:  (2, 38)  ballsHave: {(2, 37)}
# node:  (2, 40)  parent:  (2, 39)  ballsHave: set()
# node:  (2, 40)  parent:  (2, 39)  ballsHave: {(2, 37)}
# node:  (1, 40)  parent:  (2, 40)  ballsHave: set()
# node:  (1, 40)  parent:  (2, 40)  ballsHave: {(2, 37)}
# node:  (1, 39)  parent:  (2, 39)  ballsHave: set()
# node:  (1, 38)  parent:  (2, 38)  ballsHave: set()
# node:  (1, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (2, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 40)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (2, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (2, 40)  parent:  (1, 40)  ballsHave: {(2, 39)}
# node:  (2, 39)  parent:  (2, 38)  ballsHave: set()
# node:  (1, 38)  parent:  (2, 38)  ballsHave: set()
# node:  (2, 40)  parent:  (2, 39)  ballsHave: set()
# node:  (1, 39)  parent:  (2, 39)  ballsHave: set()
# node:  (1, 40)  parent:  (2, 40)  ballsHave: set()
# node:  (1, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (2, 38)  parent:  (2, 39)  ballsHave: set()
# node:  (2, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 40)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 38)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (2, 40)  parent:  (1, 40)  ballsHave: {(2, 39)}
# node:  (2, 38)  parent:  (1, 38)  ballsHave: {(2, 39)}
# node:  (1, 37)  parent:  (1, 38)  ballsHave: {(2, 39)}
# node:  (2, 37)  parent:  (2, 38)  ballsHave: {(2, 39)}
# node:  (1, 36)  parent:  (1, 37)  ballsHave: {(2, 39)}
# node:  (2, 36)  parent:  (2, 37)  ballsHave: {(2, 39)}
# node:  (1, 35)  parent:  (1, 36)  ballsHave: {(2, 39)}
# node:  (2, 35)  parent:  (2, 36)  ballsHave: {(2, 39)}
# node:  (1, 34)  parent:  (1, 35)  ballsHave: {(2, 39)}
# node:  (2, 34)  parent:  (2, 35)  ballsHave: {(2, 39)}
# node:  (1, 33)  parent:  (1, 34)  ballsHave: {(2, 39)}
# node:  (2, 33)  parent:  (2, 34)  ballsHave: {(2, 39)}
# node:  (1, 32)  parent:  (1, 33)  ballsHave: {(2, 39)}
# node:  (2, 32)  parent:  (2, 33)  ballsHave: {(2, 39)}
# node:  (1, 31)  parent:  (1, 32)  ballsHave: {(2, 39)}
# node:  (2, 31)  parent:  (2, 32)  ballsHave: {(2, 39)}
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 39)}
# node:  (2, 30)  parent:  (2, 31)  ballsHave: {(2, 39)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 39)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 39)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 39)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 39)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 39)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 39)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 39)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 39)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 39)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 39)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 39)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 39)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 39)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 39)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 39)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 39)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 39)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 39)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 39)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 39)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 39)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 39)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 39)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 39)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 39)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 39)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 39)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 39)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 39)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 39)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 39)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 39)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 39)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 39)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 39)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 39)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 39)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 39)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 39)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 39)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 39)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 39)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 39)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 39)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 39)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 39)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 39)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 39)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 39)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 39)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 39)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 39)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 39)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 39)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 39)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 39)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 39)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 39)}
# node:  (1, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (1, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (2, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (1, 39)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (1, 37)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (2, 39)  parent:  (1, 39)  ballsHave: {(2, 38)}
# node:  (1, 40)  parent:  (1, 39)  ballsHave: {(2, 38)}
# node:  (2, 40)  parent:  (2, 39)  ballsHave: {(2, 38)}
# node:  (2, 37)  parent:  (1, 37)  ballsHave: {(2, 38)}
# node:  (1, 36)  parent:  (1, 37)  ballsHave: {(2, 38)}
# node:  (2, 36)  parent:  (2, 37)  ballsHave: {(2, 38)}
# node:  (1, 35)  parent:  (1, 36)  ballsHave: {(2, 38)}
# node:  (2, 35)  parent:  (2, 36)  ballsHave: {(2, 38)}
# node:  (1, 34)  parent:  (1, 35)  ballsHave: {(2, 38)}
# node:  (2, 34)  parent:  (2, 35)  ballsHave: {(2, 38)}
# node:  (1, 33)  parent:  (1, 34)  ballsHave: {(2, 38)}
# node:  (2, 33)  parent:  (2, 34)  ballsHave: {(2, 38)}
# node:  (1, 32)  parent:  (1, 33)  ballsHave: {(2, 38)}
# node:  (2, 32)  parent:  (2, 33)  ballsHave: {(2, 38)}
# node:  (1, 31)  parent:  (1, 32)  ballsHave: {(2, 38)}
# node:  (2, 31)  parent:  (2, 32)  ballsHave: {(2, 38)}
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 38)}
# node:  (2, 30)  parent:  (2, 31)  ballsHave: {(2, 38)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 38)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 38)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 38)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 38)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 38)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 38)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 38)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 38)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 38)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 38)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 38)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 38)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 38)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 38)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 38)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 38)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 38)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 38)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 38)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 38)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 38)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 38)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 38)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 38)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 38)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 38)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 38)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 38)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 38)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 38)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 38)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 38)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 38)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 38)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 38)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 38)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 38)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 38)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 38)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 38)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 38)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 38)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 38)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 38)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 38)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 38)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 38)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 38)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 38)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 38)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 38)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 38)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 38)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 38)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 38)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 38)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 38)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 38)}
# node:  (1, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (1, 37)  parent:  (1, 38)  ballsHave: set()
# node:  (2, 37)  parent:  (2, 38)  ballsHave: set()
# node:  (1, 37)  parent:  (1, 37)  ballsHave: {(2, 37)}
# node:  (2, 36)  parent:  (2, 37)  ballsHave: set()
# node:  (2, 37)  parent:  (1, 37)  ballsHave: {(2, 37)}
# node:  (1, 38)  parent:  (1, 37)  ballsHave: {(2, 37)}
# node:  (1, 36)  parent:  (1, 37)  ballsHave: {(2, 37)}
# node:  (2, 38)  parent:  (1, 38)  ballsHave: {(2, 37)}
# node:  (1, 39)  parent:  (1, 38)  ballsHave: {(2, 37)}
# node:  (2, 39)  parent:  (2, 38)  ballsHave: {(2, 37)}
# node:  (1, 40)  parent:  (1, 39)  ballsHave: {(2, 37)}
# node:  (2, 40)  parent:  (2, 39)  ballsHave: {(2, 37)}
# node:  (2, 36)  parent:  (1, 36)  ballsHave: {(2, 37)}
# node:  (1, 35)  parent:  (1, 36)  ballsHave: {(2, 37)}
# node:  (2, 35)  parent:  (2, 36)  ballsHave: {(2, 37)}
# node:  (1, 34)  parent:  (1, 35)  ballsHave: {(2, 37)}
# node:  (2, 34)  parent:  (2, 35)  ballsHave: {(2, 37)}
# node:  (1, 33)  parent:  (1, 34)  ballsHave: {(2, 37)}
# node:  (2, 33)  parent:  (2, 34)  ballsHave: {(2, 37)}
# node:  (1, 32)  parent:  (1, 33)  ballsHave: {(2, 37)}
# node:  (2, 32)  parent:  (2, 33)  ballsHave: {(2, 37)}
# node:  (1, 31)  parent:  (1, 32)  ballsHave: {(2, 37)}
# node:  (2, 31)  parent:  (2, 32)  ballsHave: {(2, 37)}
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 37)}
# node:  (2, 30)  parent:  (2, 31)  ballsHave: {(2, 37)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 37)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 37)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 37)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 37)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 37)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 37)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 37)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 37)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 37)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 37)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 37)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 37)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 37)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 37)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 37)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 37)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 37)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 37)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 37)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 37)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 37)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 37)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 37)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 37)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 37)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 37)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 37)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 37)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 37)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 37)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 37)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 37)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 37)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 37)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 37)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 37)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 37)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 37)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 37)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 37)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 37)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 37)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 37)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 37)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 37)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 37)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 37)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 37)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 37)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 37)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 37)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 37)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 37)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 37)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 37)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 37)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 37)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 37)}
# node:  (2, 35)  parent:  (2, 36)  ballsHave: set()
# node:  (1, 36)  parent:  (1, 37)  ballsHave: set()
# node:  (1, 35)  parent:  (2, 35)  ballsHave: set()
# node:  (1, 36)  parent:  (1, 36)  ballsHave: {(2, 36)}
# node:  (1, 35)  parent:  (1, 35)  ballsHave: {(2, 35)}
# node:  (2, 36)  parent:  (1, 36)  ballsHave: {(2, 36)}
# node:  (2, 35)  parent:  (1, 35)  ballsHave: {(2, 35)}
# node:  (2, 37)  parent:  (2, 36)  ballsHave: set()
# node:  (2, 36)  parent:  (2, 35)  ballsHave: set()
# node:  (2, 38)  parent:  (2, 37)  ballsHave: set()
# node:  (2, 37)  parent:  (2, 36)  ballsHave: set()
# node:  (2, 39)  parent:  (2, 38)  ballsHave: set()
# node:  (2, 38)  parent:  (2, 37)  ballsHave: set()
# node:  (2, 40)  parent:  (2, 39)  ballsHave: set()
# node:  (2, 39)  parent:  (2, 38)  ballsHave: set()
# node:  (1, 40)  parent:  (2, 40)  ballsHave: set()
# node:  (2, 40)  parent:  (2, 39)  ballsHave: set()
# node:  (1, 39)  parent:  (2, 39)  ballsHave: set()
# node:  (1, 40)  parent:  (2, 40)  ballsHave: set()
# node:  (1, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 38)  parent:  (2, 38)  ballsHave: set()
# node:  (2, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 40)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 38)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (2, 40)  parent:  (1, 40)  ballsHave: {(2, 39)}
# node:  (2, 38)  parent:  (1, 38)  ballsHave: {(2, 39)}
# node:  (1, 37)  parent:  (1, 38)  ballsHave: {(2, 39)}
# node:  (2, 37)  parent:  (2, 38)  ballsHave: {(2, 39)}
# node:  (1, 36)  parent:  (1, 37)  ballsHave: {(2, 39)}
# node:  (2, 36)  parent:  (2, 37)  ballsHave: {(2, 39)}
# node:  (1, 35)  parent:  (1, 36)  ballsHave: {(2, 39)}
# node:  (2, 35)  parent:  (2, 36)  ballsHave: {(2, 39)}
# node:  (1, 34)  parent:  (1, 35)  ballsHave: {(2, 39)}
# node:  (2, 34)  parent:  (2, 35)  ballsHave: {(2, 39)}
# node:  (1, 33)  parent:  (1, 34)  ballsHave: {(2, 39)}
# node:  (2, 33)  parent:  (2, 34)  ballsHave: {(2, 39)}
# node:  (1, 32)  parent:  (1, 33)  ballsHave: {(2, 39)}
# node:  (2, 32)  parent:  (2, 33)  ballsHave: {(2, 39)}
# node:  (1, 31)  parent:  (1, 32)  ballsHave: {(2, 39)}
# node:  (2, 31)  parent:  (2, 32)  ballsHave: {(2, 39)}
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 39)}
# node:  (2, 30)  parent:  (2, 31)  ballsHave: {(2, 39)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 39)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 39)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 39)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 39)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 39)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 39)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 39)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 39)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 39)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 39)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 39)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 39)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 39)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 39)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 39)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 39)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 39)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 39)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 39)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 39)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 39)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 39)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 39)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 39)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 39)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 39)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 39)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 39)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 39)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 39)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 39)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 39)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 39)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 39)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 39)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 39)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 39)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 39)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 39)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 39)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 39)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 39)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 39)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 39)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 39)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 39)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 39)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 39)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 39)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 39)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 39)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 39)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 39)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 39)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 39)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 39)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 39)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 39)}
# node:  (1, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (1, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (2, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (1, 39)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (1, 37)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (2, 39)  parent:  (1, 39)  ballsHave: {(2, 38)}
# node:  (1, 40)  parent:  (1, 39)  ballsHave: {(2, 38)}
# node:  (2, 40)  parent:  (2, 39)  ballsHave: {(2, 38)}
# node:  (2, 37)  parent:  (1, 37)  ballsHave: {(2, 38)}
# node:  (1, 36)  parent:  (1, 37)  ballsHave: {(2, 38)}
# node:  (2, 36)  parent:  (2, 37)  ballsHave: {(2, 38)}
# node:  (1, 35)  parent:  (1, 36)  ballsHave: {(2, 38)}
# node:  (2, 35)  parent:  (2, 36)  ballsHave: {(2, 38)}
# node:  (1, 34)  parent:  (1, 35)  ballsHave: {(2, 38)}
# node:  (2, 34)  parent:  (2, 35)  ballsHave: {(2, 38)}
# node:  (1, 33)  parent:  (1, 34)  ballsHave: {(2, 38)}
# node:  (2, 33)  parent:  (2, 34)  ballsHave: {(2, 38)}
# node:  (1, 32)  parent:  (1, 33)  ballsHave: {(2, 38)}
# node:  (2, 32)  parent:  (2, 33)  ballsHave: {(2, 38)}
# node:  (1, 31)  parent:  (1, 32)  ballsHave: {(2, 38)}
# node:  (2, 31)  parent:  (2, 32)  ballsHave: {(2, 38)}
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 38)}
# node:  (2, 30)  parent:  (2, 31)  ballsHave: {(2, 38)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 38)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 38)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 38)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 38)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 38)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 38)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 38)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 38)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 38)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 38)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 38)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 38)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 38)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 38)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 38)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 38)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 38)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 38)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 38)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 38)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 38)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 38)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 38)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 38)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 38)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 38)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 38)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 38)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 38)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 38)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 38)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 38)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 38)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 38)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 38)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 38)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 38)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 38)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 38)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 38)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 38)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 38)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 38)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 38)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 38)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 38)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 38)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 38)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 38)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 38)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 38)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 38)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 38)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 38)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 38)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 38)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 38)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 38)}
# node:  (1, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (1, 39)  parent:  (2, 39)  ballsHave: set()
# node:  (1, 37)  parent:  (2, 37)  ballsHave: set()
# node:  (1, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 37)  parent:  (1, 37)  ballsHave: {(2, 37)}
# node:  (2, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (1, 40)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (2, 37)  parent:  (1, 37)  ballsHave: {(2, 37)}
# node:  (2, 40)  parent:  (1, 40)  ballsHave: {(2, 39)}
# node:  (1, 38)  parent:  (1, 37)  ballsHave: {(2, 37)}
# node:  (1, 38)  parent:  (1, 39)  ballsHave: {(2, 39)}
# node:  (2, 38)  parent:  (1, 38)  ballsHave: {(2, 37)}
# node:  (2, 38)  parent:  (1, 38)  ballsHave: {(2, 39)}
# node:  (2, 39)  parent:  (2, 38)  ballsHave: {(2, 37)}
# node:  (2, 37)  parent:  (2, 38)  ballsHave: {(2, 39)}
# node:  (2, 40)  parent:  (2, 39)  ballsHave: {(2, 37)}
# node:  (2, 36)  parent:  (2, 37)  ballsHave: {(2, 39)}
# node:  (1, 40)  parent:  (2, 40)  ballsHave: {(2, 37)}
# node:  (1, 36)  parent:  (2, 36)  ballsHave: {(2, 39)}
# node:  (2, 35)  parent:  (2, 36)  ballsHave: {(2, 39)}
# node:  (1, 35)  parent:  (1, 36)  ballsHave: {(2, 39)}
# node:  (2, 34)  parent:  (2, 35)  ballsHave: {(2, 39)}
# node:  (1, 34)  parent:  (1, 35)  ballsHave: {(2, 39)}
# node:  (2, 33)  parent:  (2, 34)  ballsHave: {(2, 39)}
# node:  (1, 33)  parent:  (1, 34)  ballsHave: {(2, 39)}
# node:  (2, 32)  parent:  (2, 33)  ballsHave: {(2, 39)}
# node:  (1, 32)  parent:  (1, 33)  ballsHave: {(2, 39)}
# node:  (2, 31)  parent:  (2, 32)  ballsHave: {(2, 39)}
# node:  (1, 31)  parent:  (1, 32)  ballsHave: {(2, 39)}
# node:  (2, 30)  parent:  (2, 31)  ballsHave: {(2, 39)}
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 39)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 39)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 39)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 39)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 39)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 39)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 39)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 39)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 39)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 39)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 39)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 39)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 39)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 39)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 39)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 39)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 39)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 39)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 39)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 39)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 39)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 39)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 39)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 39)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 39)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 39)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 39)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 39)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 39)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 39)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 39)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 39)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 39)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 39)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 39)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 39)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 39)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 39)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 39)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 39)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 39)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 39)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 39)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 39)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 39)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 39)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 39)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 39)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 39)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 39)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 39)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 39)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 39)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 39)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 39)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 39)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 39)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 39)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 39)}
# node:  (1, 39)  parent:  (1, 38)  ballsHave: {(2, 37)}
# node:  (1, 37)  parent:  (1, 38)  ballsHave: {(2, 39)}
# node:  (1, 36)  parent:  (1, 37)  ballsHave: {(2, 37)}
# node:  (1, 38)  parent:  (2, 38)  ballsHave: set()
# node:  (2, 36)  parent:  (1, 36)  ballsHave: {(2, 37)}
# node:  (1, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (2, 35)  parent:  (2, 36)  ballsHave: {(2, 37)}
# node:  (2, 38)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (2, 34)  parent:  (2, 35)  ballsHave: {(2, 37)}
# node:  (1, 39)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (1, 34)  parent:  (2, 34)  ballsHave: {(2, 37)}
# node:  (2, 39)  parent:  (1, 39)  ballsHave: {(2, 38)}
# node:  (1, 40)  parent:  (1, 39)  ballsHave: {(2, 38)}
# node:  (2, 40)  parent:  (2, 39)  ballsHave: {(2, 38)}
# node:  (1, 33)  parent:  (1, 34)  ballsHave: {(2, 37)}
# node:  (2, 33)  parent:  (2, 34)  ballsHave: {(2, 37)}
# node:  (1, 32)  parent:  (1, 33)  ballsHave: {(2, 37)}
# node:  (2, 32)  parent:  (2, 33)  ballsHave: {(2, 37)}
# node:  (1, 31)  parent:  (1, 32)  ballsHave: {(2, 37)}
# node:  (2, 31)  parent:  (2, 32)  ballsHave: {(2, 37)}
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 37)}
# node:  (2, 30)  parent:  (2, 31)  ballsHave: {(2, 37)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 37)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 37)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 37)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 37)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 37)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 37)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 37)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 37)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 37)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 37)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 37)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 37)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 37)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 37)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 37)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 37)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 37)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 37)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 37)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 37)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 37)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 37)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 37)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 37)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 37)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 37)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 37)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 37)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 37)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 37)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 37)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 37)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 37)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 37)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 37)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 37)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 37)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 37)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 37)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 37)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 37)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 37)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 37)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 37)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 37)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 37)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 37)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 37)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 37)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 37)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 37)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 37)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 37)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 37)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 37)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 37)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 37)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 37)}
# node:  (1, 37)  parent:  (1, 38)  ballsHave: {(2, 38)}
# node:  (1, 35)  parent:  (1, 36)  ballsHave: {(2, 37)}
# node:  (2, 37)  parent:  (1, 37)  ballsHave: {(2, 38)}
# node:  (1, 36)  parent:  (1, 37)  ballsHave: {(2, 38)}
# node:  (2, 36)  parent:  (2, 37)  ballsHave: {(2, 38)}
# node:  (1, 35)  parent:  (1, 36)  ballsHave: {(2, 38)}
# node:  (2, 35)  parent:  (2, 36)  ballsHave: {(2, 38)}
# node:  (1, 34)  parent:  (1, 35)  ballsHave: {(2, 38)}
# node:  (2, 34)  parent:  (2, 35)  ballsHave: {(2, 38)}
# node:  (1, 33)  parent:  (1, 34)  ballsHave: {(2, 38)}
# node:  (2, 33)  parent:  (2, 34)  ballsHave: {(2, 38)}
# node:  (1, 32)  parent:  (1, 33)  ballsHave: {(2, 38)}
# node:  (2, 32)  parent:  (2, 33)  ballsHave: {(2, 38)}
# node:  (1, 31)  parent:  (1, 32)  ballsHave: {(2, 38)}
# node:  (2, 31)  parent:  (2, 32)  ballsHave: {(2, 38)}
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 38)}
# node:  (2, 30)  parent:  (2, 31)  ballsHave: {(2, 38)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 38)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 38)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 38)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 38)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 38)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 38)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 38)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 38)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 38)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 38)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 38)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 38)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 38)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 38)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 38)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 38)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 38)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 38)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 38)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 38)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 38)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 38)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 38)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 38)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 38)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 38)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 38)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 38)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 38)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 38)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 38)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 38)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 38)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 38)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 38)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 38)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 38)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 38)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 38)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 38)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 38)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 38)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 38)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 38)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 38)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 38)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 38)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 38)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 38)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 38)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 38)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 38)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 38)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 38)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 38)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 38)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 38)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 38)}
# node:  (1, 36)  parent:  (2, 36)  ballsHave: set()
# node:  (2, 35)  parent:  (2, 36)  ballsHave: set()
# node:  (1, 36)  parent:  (1, 36)  ballsHave: {(2, 36)}
# node:  (1, 37)  parent:  (2, 37)  ballsHave: set()
# node:  (2, 36)  parent:  (1, 36)  ballsHave: {(2, 36)}
# node:  (1, 37)  parent:  (1, 36)  ballsHave: {(2, 36)}
# node:  (2, 37)  parent:  (2, 36)  ballsHave: set()
# node:  (2, 37)  parent:  (1, 37)  ballsHave: {(2, 36)}
# node:  (2, 38)  parent:  (2, 37)  ballsHave: set()
# node:  (2, 38)  parent:  (2, 37)  ballsHave: {(2, 36)}
# node:  (2, 39)  parent:  (2, 38)  ballsHave: set()
# node:  (2, 39)  parent:  (2, 38)  ballsHave: {(2, 36)}
# node:  (2, 40)  parent:  (2, 39)  ballsHave: set()
# node:  (2, 40)  parent:  (2, 39)  ballsHave: {(2, 36)}
# node:  (1, 40)  parent:  (2, 40)  ballsHave: set()
# node:  (1, 40)  parent:  (2, 40)  ballsHave: {(2, 36)}
# node:  (1, 39)  parent:  (2, 39)  ballsHave: {(2, 36)}
# node:  (1, 39)  parent:  (2, 39)  ballsHave: set()
# node:  (1, 38)  parent:  (2, 38)  ballsHave: set()
# node:  (1, 39)  parent:  (1, 39)  ballsHave: {(2, 39)}
# ...
# node:  (1, 37)  parent:  (2, 37)  ballsHave: {(2, 32)}
# node:  (2, 39)  parent:  (2, 38)  ballsHave: {(2, 32)}
# node:  (1, 38)  parent:  (2, 38)  ballsHave: {(2, 32)}
# node:  (2, 40)  parent:  (2, 39)  ballsHave: {(2, 32)}
# node:  (1, 39)  parent:  (2, 39)  ballsHave: {(2, 32)}
# node:  (1, 40)  parent:  (2, 40)  ballsHave: {(2, 32)}
# node:  (1, 30)  parent:  (2, 30)  ballsHave: {(2, 33)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 33)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 33)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 33)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 33)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 33)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 33)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 33)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 33)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 33)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 33)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 33)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 33)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 33)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 33)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 33)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 33)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 33)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 33)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 33)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 33)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 33)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 33)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 33)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 33)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 33)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 33)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 33)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 33)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 33)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 33)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 33)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 33)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 33)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 33)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 33)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 33)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 33)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 33)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 33)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 33)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 33)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 33)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 33)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 33)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 33)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 33)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 33)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 33)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 33)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 33)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 33)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 33)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 33)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 33)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 33)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 33)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 33)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 33)}
# node:  (1, 34)  parent:  (1, 33)  ballsHave: {(2, 32)}
# node:  (1, 31)  parent:  (1, 32)  ballsHave: {(2, 33)}
# node:  (1, 31)  parent:  (1, 32)  ballsHave: {(2, 32)}
# node:  (2, 31)  parent:  (2, 32)  ballsHave: set()
# node:  (2, 31)  parent:  (1, 31)  ballsHave: {(2, 32)}
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 32)}
# node:  (2, 30)  parent:  (2, 31)  ballsHave: {(2, 32)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 32)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 32)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 32)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 32)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 32)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 32)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 32)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 32)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 32)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 32)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 32)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 32)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 32)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 32)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 32)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 32)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 32)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 32)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 32)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 32)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 32)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 32)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 32)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 32)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 32)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 32)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 32)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 32)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 32)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 32)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 32)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 32)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 32)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 32)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 32)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 32)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 32)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 32)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 32)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 32)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 32)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 32)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 32)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 32)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 32)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 32)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 32)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 32)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 32)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 32)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 32)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 32)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 32)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 32)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 32)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 32)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 32)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 32)}
# node:  (1, 33)  parent:  (1, 32)  ballsHave: {(2, 31)}
# node:  (1, 31)  parent:  (2, 31)  ballsHave: set()
# node:  (2, 30)  parent:  (2, 31)  ballsHave: set()
# node:  (1, 31)  parent:  (1, 31)  ballsHave: {(2, 31)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: set()
# node:  (2, 31)  parent:  (1, 31)  ballsHave: {(2, 31)}
# node:  (1, 32)  parent:  (1, 31)  ballsHave: {(2, 31)}
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 31)}
# node:  (2, 32)  parent:  (1, 32)  ballsHave: {(2, 31)}
# node:  (1, 33)  parent:  (1, 32)  ballsHave: {(2, 31)}
# node:  (2, 33)  parent:  (2, 32)  ballsHave: {(2, 31)}
# node:  (1, 34)  parent:  (1, 33)  ballsHave: {(2, 31)}
# node:  (2, 34)  parent:  (2, 33)  ballsHave: {(2, 31)}
# node:  (1, 35)  parent:  (1, 34)  ballsHave: {(2, 31)}
# node:  (2, 35)  parent:  (2, 34)  ballsHave: {(2, 31)}
# node:  (1, 36)  parent:  (1, 35)  ballsHave: {(2, 31)}
# node:  (2, 36)  parent:  (2, 35)  ballsHave: {(2, 31)}
# node:  (1, 37)  parent:  (1, 36)  ballsHave: {(2, 31)}
# node:  (2, 37)  parent:  (2, 36)  ballsHave: {(2, 31)}
# node:  (1, 38)  parent:  (1, 37)  ballsHave: {(2, 31)}
# node:  (2, 38)  parent:  (2, 37)  ballsHave: {(2, 31)}
# node:  (1, 39)  parent:  (1, 38)  ballsHave: {(2, 31)}
# node:  (2, 39)  parent:  (2, 38)  ballsHave: {(2, 31)}
# node:  (1, 40)  parent:  (1, 39)  ballsHave: {(2, 31)}
# node:  (2, 40)  parent:  (2, 39)  ballsHave: {(2, 31)}
# node:  (2, 30)  parent:  (1, 30)  ballsHave: {(2, 31)}
# node:  (1, 29)  parent:  (1, 30)  ballsHave: {(2, 31)}
# node:  (2, 29)  parent:  (2, 30)  ballsHave: {(2, 31)}
# node:  (1, 28)  parent:  (1, 29)  ballsHave: {(2, 31)}
# node:  (2, 28)  parent:  (2, 29)  ballsHave: {(2, 31)}
# node:  (1, 27)  parent:  (1, 28)  ballsHave: {(2, 31)}
# node:  (2, 27)  parent:  (2, 28)  ballsHave: {(2, 31)}
# node:  (1, 26)  parent:  (1, 27)  ballsHave: {(2, 31)}
# node:  (2, 26)  parent:  (2, 27)  ballsHave: {(2, 31)}
# node:  (1, 25)  parent:  (1, 26)  ballsHave: {(2, 31)}
# node:  (2, 25)  parent:  (2, 26)  ballsHave: {(2, 31)}
# node:  (1, 24)  parent:  (1, 25)  ballsHave: {(2, 31)}
# node:  (2, 24)  parent:  (2, 25)  ballsHave: {(2, 31)}
# node:  (1, 23)  parent:  (1, 24)  ballsHave: {(2, 31)}
# node:  (2, 23)  parent:  (2, 24)  ballsHave: {(2, 31)}
# node:  (1, 22)  parent:  (1, 23)  ballsHave: {(2, 31)}
# node:  (2, 22)  parent:  (2, 23)  ballsHave: {(2, 31)}
# node:  (1, 21)  parent:  (1, 22)  ballsHave: {(2, 31)}
# node:  (2, 21)  parent:  (2, 22)  ballsHave: {(2, 31)}
# node:  (1, 20)  parent:  (1, 21)  ballsHave: {(2, 31)}
# node:  (2, 20)  parent:  (2, 21)  ballsHave: {(2, 31)}
# node:  (1, 19)  parent:  (1, 20)  ballsHave: {(2, 31)}
# node:  (2, 19)  parent:  (2, 20)  ballsHave: {(2, 31)}
# node:  (1, 18)  parent:  (1, 19)  ballsHave: {(2, 31)}
# node:  (2, 18)  parent:  (2, 19)  ballsHave: {(2, 31)}
# node:  (1, 17)  parent:  (1, 18)  ballsHave: {(2, 31)}
# node:  (2, 17)  parent:  (2, 18)  ballsHave: {(2, 31)}
# node:  (1, 16)  parent:  (1, 17)  ballsHave: {(2, 31)}
# node:  (2, 16)  parent:  (2, 17)  ballsHave: {(2, 31)}
# node:  (1, 15)  parent:  (1, 16)  ballsHave: {(2, 31)}
# node:  (2, 15)  parent:  (2, 16)  ballsHave: {(2, 31)}
# node:  (1, 14)  parent:  (1, 15)  ballsHave: {(2, 31)}
# node:  (2, 14)  parent:  (2, 15)  ballsHave: {(2, 31)}
# node:  (1, 13)  parent:  (1, 14)  ballsHave: {(2, 31)}
# node:  (2, 13)  parent:  (2, 14)  ballsHave: {(2, 31)}
# node:  (1, 12)  parent:  (1, 13)  ballsHave: {(2, 31)}
# node:  (2, 12)  parent:  (2, 13)  ballsHave: {(2, 31)}
# node:  (1, 11)  parent:  (1, 12)  ballsHave: {(2, 31)}
# node:  (2, 11)  parent:  (2, 12)  ballsHave: {(2, 31)}
# node:  (1, 10)  parent:  (1, 11)  ballsHave: {(2, 31)}
# node:  (2, 10)  parent:  (2, 11)  ballsHave: {(2, 31)}
# node:  (1, 9)  parent:  (1, 10)  ballsHave: {(2, 31)}
# node:  (2, 9)  parent:  (2, 10)  ballsHave: {(2, 31)}
# node:  (1, 8)  parent:  (1, 9)  ballsHave: {(2, 31)}
# node:  (2, 8)  parent:  (2, 9)  ballsHave: {(2, 31)}
# node:  (1, 7)  parent:  (1, 8)  ballsHave: {(2, 31)}
# node:  (2, 7)  parent:  (2, 8)  ballsHave: {(2, 31)}
# node:  (1, 6)  parent:  (1, 7)  ballsHave: {(2, 31)}
# node:  (2, 6)  parent:  (2, 7)  ballsHave: {(2, 31)}
# node:  (1, 5)  parent:  (1, 6)  ballsHave: {(2, 31)}
# node:  (2, 5)  parent:  (2, 6)  ballsHave: {(2, 31)}
# node:  (1, 4)  parent:  (1, 5)  ballsHave: {(2, 31)}
# node:  (2, 4)  parent:  (2, 5)  ballsHave: {(2, 31)}
# node:  (1, 3)  parent:  (1, 4)  ballsHave: {(2, 31)}
# node:  (2, 3)  parent:  (2, 4)  ballsHave: {(2, 31)}
# node:  (1, 2)  parent:  (1, 3)  ballsHave: {(2, 31)}
# node:  (2, 2)  parent:  (2, 3)  ballsHave: {(2, 31)}
# node:  (1, 1)  parent:  (1, 2)  ballsHave: {(2, 31)}
# node:  (2, 1)  parent:  (2, 2)  ballsHave: {(2, 31)}
# node:  (1, 29)  parent:  (2, 29)  ballsHave: set()
# node:  (2, 28)  parent:  (2, 29)  ballsHave: set()
# node:  (1, 28)  parent:  (1, 29)  ballsHave: set()
# node:  (2, 27)  parent:  (2, 28)  ballsHave: set()
# node:  (1, 27)  parent:  (1, 28)  ballsHave: set()
# node:  (2, 26)  parent:  (2, 27)  ballsHave: set()
# node:  (1, 26)  parent:  (1, 27)  ballsHave: set()
# node:  (2, 25)  parent:  (2, 26)  ballsHave: set()
# node:  (1, 25)  parent:  (1, 26)  ballsHave: set()
# node:  (2, 24)  parent:  (2, 25)  ballsHave: set()
# node:  (1, 24)  parent:  (1, 25)  ballsHave: set()
# node:  (2, 23)  parent:  (2, 24)  ballsHave: set()
# node:  (1, 23)  parent:  (1, 24)  ballsHave: set()
# node:  (2, 22)  parent:  (2, 23)  ballsHave: set()
# node:  (1, 22)  parent:  (1, 23)  ballsHave: set()
# node:  (2, 21)  parent:  (2, 22)  ballsHave: set()
# node:  (1, 21)  parent:  (1, 22)  ballsHave: set()
# node:  (2, 20)  parent:  (2, 21)  ballsHave: set()
# node:  (1, 20)  parent:  (1, 21)  ballsHave: set()
# node:  (2, 19)  parent:  (2, 20)  ballsHave: set()
# node:  (1, 19)  parent:  (1, 20)  ballsHave: set()
# node:  (2, 18)  parent:  (2, 19)  ballsHave: set()
# node:  (1, 18)  parent:  (1, 19)  ballsHave: set()
# node:  (2, 17)  parent:  (2, 18)  ballsHave: set()
# node:  (1, 17)  parent:  (1, 18)  ballsHave: set()
# node:  (2, 16)  parent:  (2, 17)  ballsHave: set()
# node:  (1, 16)  parent:  (1, 17)  ballsHave: set()
# node:  (2, 15)  parent:  (2, 16)  ballsHave: set()
# node:  (1, 15)  parent:  (1, 16)  ballsHave: set()
# node:  (2, 14)  parent:  (2, 15)  ballsHave: set()
# node:  (1, 14)  parent:  (1, 15)  ballsHave: set()
# node:  (2, 13)  parent:  (2, 14)  ballsHave: set()
# node:  (1, 13)  parent:  (1, 14)  ballsHave: set()
# node:  (2, 12)  parent:  (2, 13)  ballsHave: set()
# node:  (1, 12)  parent:  (1, 13)  ballsHave: set()
# node:  (2, 11)  parent:  (2, 12)  ballsHave: set()
# node:  (1, 11)  parent:  (1, 12)  ballsHave: set()
# node:  (2, 10)  parent:  (2, 11)  ballsHave: set()
# node:  (1, 10)  parent:  (1, 11)  ballsHave: set()
# node:  (2, 9)  parent:  (2, 10)  ballsHave: set()
# node:  (1, 9)  parent:  (1, 10)  ballsHave: set()
# node:  (2, 8)  parent:  (2, 9)  ballsHave: set()
# node:  (1, 8)  parent:  (1, 9)  ballsHave: set()
# node:  (2, 7)  parent:  (2, 8)  ballsHave: set()
# node:  (1, 7)  parent:  (1, 8)  ballsHave: set()
# node:  (2, 6)  parent:  (2, 7)  ballsHave: set()
# node:  (1, 6)  parent:  (1, 7)  ballsHave: set()
# node:  (2, 5)  parent:  (2, 6)  ballsHave: set()
# node:  (1, 5)  parent:  (1, 6)  ballsHave: set()
# node:  (2, 4)  parent:  (2, 5)  ballsHave: set()
# node:  (1, 4)  parent:  (1, 5)  ballsHave: set()
# node:  (2, 3)  parent:  (2, 4)  ballsHave: set()
# node:  (1, 3)  parent:  (1, 4)  ballsHave: set()
# node:  (2, 2)  parent:  (2, 3)  ballsHave: set()
# node:  (1, 2)  parent:  (1, 3)  ballsHave: set()
# node:  (2, 1)  parent:  (2, 2)  ballsHave: set()
# node:  (1, 1)  parent:  (1, 2)  ballsHave: set()
# node:  (1, 30)  parent:  (1, 31)  ballsHave: set()
# node:  (1, 30)  parent:  (1, 31)  ballsHave: {(2, 31)}
# node:  (1, 30)  parent:  (1, 30)  ballsHave: {(2, 30)}
# node:  (2, 30)  parent:  (1, 30)  ballsHave: {(2, 31)}
# node:  (2, 30)  parent:  (1, 30)  ballsHave: {(2, 30)}
# node:  (1, 31)  parent:  (1, 30)  ballsHave: {(2, 30)}
# node:  (2, 31)  parent:  (2, 30)  ballsHave: set()
# node:  (2, 31)  parent:  (1, 31)  ballsHave: {(2, 30)}
# node:  (2, 32)  parent:  (2, 31)  ballsHave: set()
# node:  (2, 32)  parent:  (2, 31)  ballsHave: {(2, 30)}
# node:  (2, 33)  parent:  (2, 32)  ballsHave: set()
# node:  (2, 33)  parent:  (2, 32)  ballsHave: {(2, 30)}
# node:  (2, 34)  parent:  (2, 33)  ballsHave: set()
# node:  (2, 34)  parent:  (2, 33)  ballsHave: {(2, 30)}
# node:  (2, 35)  parent:  (2, 34)  ballsHave: set()
# node:  (2, 35)  parent:  (2, 34)  ballsHave: {(2, 30)}
# node:  (2, 36)  parent:  (2, 35)  ballsHave: set()
# node:  (2, 36)  parent:  (2, 35)  ballsHave: {(2, 30)}
# node:  (2, 37)  parent:  (2, 36)  ballsHave: set()
# node:  (2, 37)  parent:  (2, 36)  ballsHave: {(2, 30)}
# node:  (2, 38)  parent:  (2, 37)  ballsHave: set()
# node:  (2, 38)  parent:  (2, 37)  ballsHave: {(2, 30)}
# node:  (2, 39)  parent:  (2, 38)  ballsHave: set()
# solDistance 92
# stateSeen 14864
# stateSeenUnique 3690
# time it took: 2.962341785430908 sec
#
# Avg time for three operations: 2.962341785430908 sec
#
# ---------------------------------------------------------

# %% [markdown]
# ##  <font color='brown'>Part E: Second A* </font>

# %%
def Astar_2(startPointNode, finalPointNode, bagCapacity, numBalls, ballsPos, maze):
    frontier = []
    frontierSet = set() #ONLY saves hash(ballsPlaced + ballsHave + state)
    explored = set() #ONLY saves hash(ballsPlaced + ballsHave + state)
    actions = [[0,1],[1,0],[0,-1],[-1,0]] # right-down-left-up
    solDistance, stateSeen, stateSeenUnique = 0,0,0
    startPointNode.setHeuristic(secondHeuristic(startPointNode,finalPointNode,ballsPos)+startPointNode.getDepth())
    frontier.append(startPointNode)
    frontierSet.add(hash(str(startPointNode.getBallsPlaced())+str(startPointNode.getBallsHave())+str(startPointNode.getState())))
    if(goalTest(startPointNode, finalPointNode, ballsPos)):
        return 0,1,1
    while(frontier):
        node = frontier.pop() #Every Iteration minimum Heuristic goes to the end of list
#         if(node.getParent()):
#             print("node: ",node.getState()," parent: ",((node.getParent()).getState())," ballsHave:",node.getBallsHave())
        if(hash(str(node.getBallsPlaced())+str(node.getBallsHave())+str(node.getState())) in frontierSet):
            frontierSet.remove(hash(str(node.getBallsPlaced())+str(node.getBallsHave())+str(node.getState())))
        explored.add(hash(str(node.getBallsPlaced())+str(node.getBallsHave())+str(node.getState())))
        if(node.getState() in node.getBallsHave()):
            node.addBallsPlaced(node.getState())
            node.removeBallsHave(node.getState())
        for action in actions:
            child = Node([node.getState()[0]+action[0], node.getState()[1]+action[1]])
            child.setParent(node)
            child.setDepth(node.getDepth()+1)
            child.setBallsHave(node.getBallsHave())
            child.setBallsPlaced(node.getBallsPlaced())
            stateSeen = stateSeen+1
            if((hash(str(child.getBallsPlaced())+str(child.getBallsHave())+str(child.getState())) not in explored) 
               and (hash(str(child.getBallsPlaced())+str(child.getBallsHave())+str(child.getState())) not in frontierSet)): 
                if(pathAvailable(child,maze)):
                   stateSeenUnique = stateSeenUnique+1
                   if(goalTest(child, finalPointNode, ballsPos)):
#                        child.printPath(child)
                       solDistance = child.getDepth()
                       return solDistance, stateSeen, stateSeenUnique
                   child.setHeuristic(secondHeuristic(child,finalPointNode,ballsPos)+child.getDepth())
                   for i in range(len(frontier)):
                       if((child.getHeuristic() < frontier[i].getHeuristic()) or(i == len(frontier)-1) ):
                           frontier.insert(i,child)
                           frontierSet.add(hash(str(child.getBallsPlaced())+str(child.getBallsHave())+str(child.getState())))
                           break
                   if(len(frontier) == 0):
                       frontier.append(child)
                       frontierSet.add(hash(str(child.getBallsPlaced())+str(child.getBallsPlaced())+str(child.getBallsHave())+str(child.getState())))
            ####### Ball handing
            if((action == [-1,0]) and (len(node.getBallsHave())<bagCapacity)):
                if((action == [-1,0]) and (node.getState() in ballsPos) and (node.getState() not in child.getBallsHave()) and (node.getState() not in child.getBallsPlaced())):
                    child_withBall = Node([node.getState()[0],node.getState()[1]])
                    child_withBall.setParent(node)
                    child_withBall.setDepth(node.getDepth()+1)
                    child_withBall.setBallsHave(node.getBallsHave())
                    child_withBall.setBallsPlaced(node.getBallsPlaced())
                    stateSeen = stateSeen+1
                    ballPicked = ballsPos.get(node.getState()) 
                    child_withBall.addBallsHave(ballPicked)
                    child_withBall.setHeuristic(secondHeuristic(child_withBall,finalPointNode,ballsPos)+child_withBall.getDepth())
                    for i in range(len(frontier)):
                       if((child_withBall.getHeuristic() < frontier[i].getHeuristic()) or(i == len(frontier)-1) ):
                           frontier.insert(i,child_withBall)
                           frontierSet.add(hash(str(child_withBall.getBallsPlaced())+str(child_withBall.getBallsHave())+str(child_withBall.getState())))
    return -1, stateSeen, stateSeenUnique

# %%
M=3
print("\n\nmap",M,": ")
mazeName = str(M)+".txt"
file = open(mazeName,'r')
lines = file.readlines()
count = 0
countBallsTemp =0
for line in lines:
    line = line.split()
    if(count ==0):
        n, m = int(line[0]),int(line[1])
        maze = []
        count +=1
    elif(count ==1):
        startPoint = [int(line[0]),int(line[1])]
        count +=1
    elif(count == 2):
        finalPoint = [int(line[0]),int(line[1])]
        count +=1
    elif(count == 3):
        bagCapacity = int(line[0])
        count +=1
    elif(count == 4):
        numBalls = int(line[0])
        countBallsTemp = numBalls
        ballsPos = {}
        count +=1
    elif(count >4 and countBallsTemp>0):
        ballsPos.update({(int(line[0]),int(line[1])):(int(line[2]),int(line[3]))})
        countBallsTemp -=1
        count +=1
    else:
        maze.append(line)
timeConsumed = []
# for i in range(3):
startPointNode = Node(startPoint)
finalPointNode = Node(finalPoint)
bagCapacity_map = bagCapacity
numBalls_map = numBalls
ballsPos_map = ballsPos
startTime = time.time()
solDistance, stateSeen, stateSeenUnique = Astar_2(startPointNode, finalPointNode, bagCapacity_map, numBalls_map, ballsPos_map, maze)
endTime = time.time()
timeConsumed.append(endTime-startTime)
print("solDistance",solDistance)
print("stateSeen",stateSeen)
print("stateSeenUnique",stateSeenUnique)
print("time it took:",(endTime-startTime),"sec")
print("\nAvg time for three operations:",(sum(timeConsumed)),"sec")
print("\n---------------------------------------------------------\n")
# Out:
# map 3 :
# solDistance 68
# stateSeen 117069
# stateSeenUnique 29470
# time it took: 8.528509855270386 sec
#
# Avg time for three operations: 8.528509855270386 sec
#
# ---------------------------------------------------------
